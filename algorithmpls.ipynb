# %%
import random
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %% [markdown]
# # Mutation

# %%
column_names = [str(i) for i in range(1, 31)]
#test1= pd.read_csv("./single_point_slots_co.csv", names= column_names)
#test1.head()

# %%
day_swap= pd.read_csv("./day_swap.csv", names= column_names)
day_swap.head()
# Out:
#                                       1                                     2  \
# 0  Individual(size=51); Fitness: 2116.5  Individual(size=51); Fitness: 2116.5
# 1  Individual(size=51); Fitness: 2063.5  Individual(size=51); Fitness: 2055.5
# 2  Individual(size=51); Fitness: 3591.0  Individual(size=51); Fitness: 3591.0
# 3  Individual(size=51); Fitness: 2843.5  Individual(size=51); Fitness: 2843.5
# 4  Individual(size=51); Fitness: 2649.0  Individual(size=51); Fitness: 2203.5
#
#                                       3                                     4  \
# 0  Individual(size=51); Fitness: 2116.5  Individual(size=51); Fitness: 2116.5
# 1  Individual(size=51); Fitness: 2055.5  Individual(size=51); Fitness: 2055.5
# 2  Individual(size=51); Fitness: 3329.5  Individual(size=51); Fitness: 2761.5
# 3  Individual(size=51); Fitness: 2843.5  Individual(size=51); Fitness: 2843.5
# 4  Individual(size=51); Fitness: 2203.5  Individual(size=51); Fitness: 2203.5
#
#                                       5                                     6  \
# 0  Individual(size=51); Fitness: 1972.5  Individual(size=51); Fitness: 1972.5
# 1  Individual(size=51); Fitness: 2055.5  Individual(size=51); Fitness: 2055.5
# 2  Individual(size=51); Fitness: 2473.5  Individual(size=51); Fitness: 2473.5
# 3  Individual(size=51); Fitness: 2843.5  Individual(size=51); Fitness: 2843.5
# 4  Individual(size=51); Fitness: 2165.5  Individual(size=51); Fitness: 2165.5
#
#                                       7                                     8  \
# 0  Individual(size=51); Fitness: 1951.5  Individual(size=51); Fitness: 1951.5
# 1  Individual(size=51); Fitness: 2055.5  Individual(size=51); Fitness: 2055.5
# 2  Individual(size=51); Fitness: 2473.5  Individual(size=51); Fitness: 2473.5
# 3  Individual(size=51); Fitness: 2843.5  Individual(size=51); Fitness: 2661.0
# 4  Individual(size=51); Fitness: 2165.5  Individual(size=51); Fitness: 2165.5
#
#                                       9                                    10  \
# 0  Individual(size=51); Fitness: 1951.5  Individual(size=51); Fitness: 1951.5
# 1  Individual(size=51); Fitness: 2055.5  Individual(size=51); Fitness: 2055.5
# 2  Individual(size=51); Fitness: 2473.5  Individual(size=51); Fitness: 2473.5
# 3  Individual(size=51); Fitness: 2661.0  Individual(size=51); Fitness: 2661.0
# 4  Individual(size=51); Fitness: 2165.5  Individual(size=51); Fitness: 2165.5
#
#    ...                                    21  \
# 0  ...  Individual(size=51); Fitness: 1595.5
# 1  ...   Individual(size=51); Fitness: 904.5
# 2  ...  Individual(size=51); Fitness: 2061.5
# 3  ...  Individual(size=51); Fitness: 2661.0
# 4  ...  Individual(size=51); Fitness: 2165.5
#
#                                      22                                    23  \
# 0  Individual(size=51); Fitness: 1595.5  Individual(size=51); Fitness: 1595.5
# 1   Individual(size=51); Fitness: 730.0   Individual(size=51); Fitness: 730.0
# 2  Individual(size=51); Fitness: 1713.0  Individual(size=51); Fitness: 1713.0
# 4  Individual(size=51); Fitness: 472.0
#
# [5 rows x 30 columns]

# %%
timeslot_swap = pd.read_csv("./timeslot_swap.csv", names= column_names)
timeslot_swap.head()
# Out:
#                                       1                                     2  \
# 0  Individual(size=51); Fitness: 4313.0  Individual(size=51); Fitness: 4036.5
# 1  Individual(size=51); Fitness: 2516.5  Individual(size=51); Fitness: 2506.0
# 2  Individual(size=51); Fitness: 1816.5  Individual(size=51); Fitness: 1566.5
# 3  Individual(size=51); Fitness: 3268.0  Individual(size=51); Fitness: 2798.0
# 4  Individual(size=51); Fitness: 3048.5  Individual(size=51); Fitness: 2935.0
#
#                                       3                                     4  \
# 0  Individual(size=51); Fitness: 3887.0  Individual(size=51); Fitness: 3739.5
# 1  Individual(size=51); Fitness: 2439.5  Individual(size=51); Fitness: 2075.5
# 2  Individual(size=51); Fitness: 1566.5  Individual(size=51); Fitness: 1566.5
# 3  Individual(size=51); Fitness: 2664.5  Individual(size=51); Fitness: 2447.5
# 4  Individual(size=51); Fitness: 2841.5  Individual(size=51); Fitness: 2841.5
#
#                                       5                                     6  \
# 0  Individual(size=51); Fitness: 2506.0  Individual(size=51); Fitness: 2506.0
# 1  Individual(size=51); Fitness: 1724.5  Individual(size=51); Fitness: 1587.5
# 2  Individual(size=51); Fitness: 1566.5  Individual(size=51); Fitness: 1566.5
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                       7                                     8  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1  Individual(size=51); Fitness: 1517.5  Individual(size=51); Fitness: 1454.5
# 2  Individual(size=51); Fitness: 1566.5  Individual(size=51); Fitness: 1566.5
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                       9                                    10  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1  Individual(size=51); Fitness: 1390.0  Individual(size=51); Fitness: 1247.5
# 2  Individual(size=51); Fitness: 1566.5  Individual(size=51); Fitness: 1566.5
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#    ...                                    21  \
# 0  ...  Individual(size=51); Fitness: 2243.5
# 1  ...   Individual(size=51); Fitness: 987.5
# 2  ...  Individual(size=51); Fitness: 1464.5
# 3  ...  Individual(size=51); Fitness: 2046.0
# 4  ...  Individual(size=51); Fitness: 2704.5
#
#                                      22                                    23  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1   Individual(size=51); Fitness: 987.5   Individual(size=51); Fitness: 987.5
# 2  Individual(size=51); Fitness: 1464.5  Individual(size=51); Fitness: 1464.5
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                      24                                    25  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1   Individual(size=51); Fitness: 987.5   Individual(size=51); Fitness: 987.5
# 2  Individual(size=51); Fitness: 1423.0  Individual(size=51); Fitness: 1423.0
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                      26                                    27  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1   Individual(size=51); Fitness: 987.5   Individual(size=51); Fitness: 987.5
# 2  Individual(size=51); Fitness: 1353.0  Individual(size=51); Fitness: 1331.0
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2046.0
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                      28                                    29  \
# 0  Individual(size=51); Fitness: 2243.5  Individual(size=51); Fitness: 2243.5
# 1   Individual(size=51); Fitness: 901.5   Individual(size=51); Fitness: 901.5
# 2  Individual(size=51); Fitness: 1331.0  Individual(size=51); Fitness: 1312.5
# 3  Individual(size=51); Fitness: 2046.0  Individual(size=51); Fitness: 2009.5
# 4  Individual(size=51); Fitness: 2704.5  Individual(size=51); Fitness: 2704.5
#
#                                      30
# 0  Individual(size=51); Fitness: 2243.5
# 1   Individual(size=51); Fitness: 901.5
# 2  Individual(size=51); Fitness: 1312.5
# 3  Individual(size=51); Fitness: 1981.0
# 4  Individual(size=51); Fitness: 2704.5
#
# [5 rows x 30 columns]

# %%
def extract_number(cell):
    match = re.search(r'(\d+\.?\d*)$', cell)
    if match:
        return match.group(1)
    else:
        return None

# %%
inversion = inversion.applymap(extract_number).astype(float)
timeslot_swap = timeslot_swap.applymap(extract_number).astype(float)
day_swap = day_swap.applymap(extract_number).astype(float)

# %%
clrs = sns.color_palette("husl", 3)

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharey=True)

custom_palette = ["#fd7f6f", "#7eb0d5", "#b2e061"]
for i, ax in enumerate(axes.flatten()):
# Select the dataset for the current box plot
    if i == 0:
        dataset = inversion
        title = "Inversion"
    elif i == 1:
        dataset = day_swap
        title = "Day Swap"
    elif i == 2:
        dataset = timeslot_swap
        title = "Timeslot Swap"
    
    # Create the box plot
    sns.boxplot(data=dataset, color=custom_palette[i], ax=ax)
    
    # Adjust y-axis limit to accommodate the maximum value
    ax.set_ylim(0, 5000)
    ax.set_xlabel(title)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
unpivoted_df1 = pd.melt(inversion, var_name='Generation', value_name='Fitness_inversion')
unpivoted_df2 = pd.melt(day_swap, var_name='Generation', value_name='Fitness_day_swap')
unpivoted_df3 = pd.melt(timeslot_swap, var_name='Generation', value_name='Fitness_timeslot_swap')
unpivoted_df = pd.merge(unpivoted_df1, unpivoted_df2, left_index=True, right_index=True)
unpivoted_df = pd.merge(unpivoted_df, unpivoted_df3, left_index=True, right_index=True)
unpivoted_df.drop(["Generation_x","Generation_y"], axis=1, inplace=True)
unpivoted_df
# Out:
#      Fitness_inversion  Fitness_day_swap Generation  Fitness_timeslot_swap
# 0               2674.0            2116.5          1                 4313.0
# 1                451.0            2063.5          1                 2516.5
# 2               2509.5            3591.0          1                 1816.5
# 3               2551.5            2843.5          1                 3268.0
# 4               1908.5            2649.0          1                 3048.5
# ..                 ...               ...        ...                    ...
# 295               37.5             121.5         30                 2149.0
# 296              437.0            1819.5         30                 1058.5
# 297               11.5              71.0         30                 1815.5
# 298               60.5             421.0         30                 2195.0
# 299                9.5            2051.0         30                  754.0
#
# [300 rows x 4 columns]

# %%
# Reshape the data into a long format
df_long = unpivoted_df.melt(id_vars='Generation', value_vars=['Fitness_inversion', 'Fitness_day_swap', 'Fitness_timeslot_swap'],
                            var_name='Method', value_name='Fitness')
# Create the line plot
sns.lineplot(data=df_long, x='Generation', y='Fitness', hue='Method')

# Set plot title and y-axis limit
plt.title('Fitness by Generation')
plt.ylim(0)

# Display the plot
plt.show()

# %%
# Calculate mean and standard deviation for each column
means = test1.mean()
stds = test1.std()
# Plot the line plot
plt.errorbar(x=means.index, y=means, yerr=stds, fmt='o-', capsize=3)
plt.xlabel('Columns')
plt.ylabel('Mean Observation')
plt.title('Line Plot with Uncertainty')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Calculate mean and standard deviation for each column
# ----> 2 means = test1.mean()
#       3 stds = test1.std()
#       4 # Plot the line plot
#
# NameError: name 'test1' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

mean_values = test1.mean()
std_values = test1.std()

plt.scatter(range(1, 11), mean_values)
#plt.errorbar(range(1, 11), mean_values, yerr=std_values, fmt="o")
plt.errorbar(range(1, 11), mean_values, yerr=std_values, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0)
plt.xlabel("Column")
plt.ylabel("Mean Observation")
plt.title("Scatter Plot with Uncertainty")
plt.show()

# %% [markdown]
# # Crossover

# %%
single_point_slots_co= pd.read_csv("./single_point_slots_co.csv", names= column_names)
single_point_slots_co.head()
# Out:
#         1       2       3       4       5       6       7       8       9  \
# 0  2663.5  2524.5  2524.5  2524.5  2524.5  2524.5  2431.5  2379.5  2379.5
# 1  2874.5  2450.5  2450.5  2450.5  2429.5  2429.5  2429.5  2142.0  2142.0
# 2  2813.5  2813.5  2591.0  2567.5  2375.5  2375.5  2375.5  2375.5  2375.5
# 3  2516.0  2440.0  2440.0  2199.0  2195.0  2195.0  2195.0  2195.0  2195.0
# 4  2359.5  2359.5  2359.5  2359.5  2359.5  2191.0  2191.0  2191.0  2191.0
#
#        10  ...      21      22      23      24      25      26      27  \
# 0  2379.5  ...  2379.5  2379.5  2379.5  2379.5  2379.5  2273.5  2273.5
# 1  2112.0  ...  1298.5  1211.0  1211.0  1153.0  1083.0  1057.0   962.5
# 2  2194.5  ...  1039.0   971.0   971.0   943.0   875.0   864.0   613.0
# 3  2195.0  ...  1621.5  1621.5  1621.5  1621.5  1621.5  1583.0  1552.5
# 4  2191.0  ...  2191.0  2163.5  2163.5  2089.0  2089.0  2089.0  2089.0
# 3   Individual(size=51); Fitness: 742.0   Individual(size=51); Fitness: 742.0
# 4   Individual(size=51); Fitness: 656.5   Individual(size=51); Fitness: 313.5
#
#                                      24                                    25  \
# 0  Individual(size=51); Fitness: 2067.0  Individual(size=51); Fitness: 2067.0
# 1   Individual(size=51); Fitness: 165.5   Individual(size=51); Fitness: 165.5
# 2   Individual(size=51); Fitness: 214.5   Individual(size=51); Fitness: 207.5
# 3   Individual(size=51); Fitness: 742.0   Individual(size=51); Fitness: 742.0
# 4   Individual(size=51); Fitness: 227.0   Individual(size=51); Fitness: 102.5
#
#                                      26                                    27  \
# 0  Individual(size=51); Fitness: 2067.0  Individual(size=51); Fitness: 2067.0
# 1   Individual(size=51); Fitness: 141.0   Individual(size=51); Fitness: 141.0
# 2   Individual(size=51); Fitness: 200.5   Individual(size=51); Fitness: 200.5
# 3   Individual(size=51); Fitness: 742.0   Individual(size=51); Fitness: 742.0
# 4    Individual(size=51); Fitness: 89.5    Individual(size=51); Fitness: 89.5
#
#                                      28                                    29  \
# 0  Individual(size=51); Fitness: 1914.0  Individual(size=51); Fitness: 1914.0
# 1   Individual(size=51); Fitness: 141.0    Individual(size=51); Fitness: 99.5
# 2   Individual(size=51); Fitness: 200.5   Individual(size=51); Fitness: 200.5
# 3   Individual(size=51); Fitness: 742.0   Individual(size=51); Fitness: 742.0
# 4    Individual(size=51); Fitness: 89.5    Individual(size=51); Fitness: 71.5
#
#                                      30
# 0  Individual(size=51); Fitness: 1914.0
# 1    Individual(size=51); Fitness: 99.5
# 2   Individual(size=51); Fitness: 196.5
# 3   Individual(size=51); Fitness: 742.0
# 4    Individual(size=51); Fitness: 25.0
#
# [5 rows x 30 columns]

# %%
order_timeslots_crossover= pd.read_csv("./order_timeslots_crossover.csv", names= column_names)
order_timeslots_crossover.head()
# Out:
#                                       1                                     2  \
# 0  Individual(size=51); Fitness: 4858.5  Individual(size=51); Fitness: 2891.0
# 1   Individual(size=51); Fitness: 818.5   Individual(size=51); Fitness: 818.5
# 2  Individual(size=51); Fitness: 2878.5  Individual(size=51); Fitness: 2184.0
# 3  Individual(size=51); Fitness: 3289.5  Individual(size=51); Fitness: 3289.5
# 4  Individual(size=51); Fitness: 4078.5  Individual(size=51); Fitness: 4078.5
#
#                                       3                                     4  \
# 0  Individual(size=51); Fitness: 2629.5  Individual(size=51); Fitness: 2350.0
# 1   Individual(size=51); Fitness: 818.5   Individual(size=51); Fitness: 818.5
# 2  Individual(size=51); Fitness: 1866.5  Individual(size=51); Fitness: 1866.5
# 3  Individual(size=51); Fitness: 2898.5  Individual(size=51); Fitness: 2898.5
# 4  Individual(size=51); Fitness: 3116.5  Individual(size=51); Fitness: 2808.5
#
#                                       5                                     6  \
# 0  Individual(size=51); Fitness: 2350.0  Individual(size=51); Fitness: 2350.0
# 1   Individual(size=51); Fitness: 674.5   Individual(size=51); Fitness: 674.5
# 2  Individual(size=51); Fitness: 1866.5  Individual(size=51); Fitness: 1866.5
# 3  Individual(size=51); Fitness: 2898.5  Individual(size=51); Fitness: 2898.5
# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharey=True)

custom_palette = ["#fd7f6f", "#7eb0d5", "#b2e061"]
for i, ax in enumerate(axes.flatten()):
# Select the dataset for the current box plot
    if i == 0:
        dataset = single_point_slots_co
        title = "Single Point Slots Co"
    elif i == 1:
        dataset = cycle_xo
        title = "Cycle Xo"
    elif i == 2:
        dataset = order_timeslots_crossover
        title = "Order Timeslots Crossover"
    
    # Create the box plot
    sns.boxplot(data=dataset, color=custom_palette[i], ax=ax)
    
    # Adjust y-axis limit to accommodate the maximum value
    ax.set_ylim(0, 5000)
    ax.set_xlabel(title)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
unpivoted_df1 = pd.melt(single_point_slots_co, var_name='Generation', value_name='Fitness_single_point_slots_co')
unpivoted_df2 = pd.melt(cycle_xo, var_name='Generation', value_name='Fitness_cycle_xo')
unpivoted_df3 = pd.melt(order_timeslots_crossover, var_name='Generation', value_name='Fitness_order_timeslots_crossover')
unpivoted_df = pd.merge(unpivoted_df1, unpivoted_df2, left_index=True, right_index=True)
unpivoted_df = pd.merge(unpivoted_df, unpivoted_df3, left_index=True, right_index=True)
unpivoted_df.drop(["Generation_x","Generation_y"], axis=1, inplace=True)
unpivoted_df
# Out:
#      Fitness_single_point_slots_co  Fitness_cycle_xo Generation  \
# 0                           2663.5            3947.0          1
# 1                           2874.5            3341.0          1
# 2                           2813.5            2565.5          1
# 3                           2516.0             742.0          1
# 4                           2359.5            2697.5          1
# ..                             ...               ...        ...
# 295                          917.0             766.0         30
# 296                         1523.0             389.0         30
# 297                         2273.5             428.5         30
# 298                          760.0             666.5         30
# 299                          613.0             651.5         30
#
#      Fitness_order_timeslots_crossover
# 0                               4858.5
# 1                                818.5
# 2                               2878.5
# 3                               3289.5
# 4                               4078.5
# ..                                 ...
# 295                             1172.0
# 296                             1875.5
# 297                             1609.0
# 298                              581.5
# 299                              279.0
#
# [300 rows x 4 columns]

# %%
# Reshape the data into a long format
df_long = unpivoted_df.melt(id_vars='Generation', value_vars=['Fitness_single_point_slots_co', 'Fitness_cycle_xo', 'Fitness_order_timeslots_crossover'],
                            var_name='Method', value_name='Fitness')
# Create the line plot
sns.lineplot(data=df_long, x='Generation', y='Fitness', hue='Method')

# Set plot title and y-axis limit
plt.title('Fitness by Generation')
plt.ylim(0)

# Display the plot
plt.show()

# %% [markdown]
# # Selection

# %%
ranking_sel = pd.read_csv("./ranking_sel.csv", names= column_names)
ranking_sel.head()
# Out:
#         1       2       3       4       5       6       7       8       9  \
# 0  1885.5  1885.5  1885.5  1885.5  1885.5  1767.5  1767.5  1767.5  1767.5
# 1  2522.5  2522.5  2505.0  2505.0  2389.5  2113.5  2113.5  2113.5  2053.5
# 2  2522.5  2470.5  2470.5  2470.5  2470.5  2470.5  1792.5  1792.5  1792.5
# 3  Individual(size=51); Fitness: 1345.0  Individual(size=51); Fitness: 1345.0
# 4  Individual(size=51); Fitness: 1170.0  Individual(size=51); Fitness: 1170.0
#
#                                      28                                    29  \
# 0  Individual(size=51); Fitness: 1838.0  Individual(size=51); Fitness: 1838.0
# 1  Individual(size=51); Fitness: 1801.5  Individual(size=51); Fitness: 1796.0
# 2  Individual(size=51); Fitness: 1703.5  Individual(size=51); Fitness: 1703.5
# 3  Individual(size=51); Fitness: 1345.0  Individual(size=51); Fitness: 1345.0
# 4  Individual(size=51); Fitness: 1170.0  Individual(size=51); Fitness: 1170.0
#
#                                      30
# 0  Individual(size=51); Fitness: 1838.0
# 1  Individual(size=51); Fitness: 1736.0
# 2  Individual(size=51); Fitness: 1703.5
# 3  Individual(size=51); Fitness: 1345.0
# 4  Individual(size=51); Fitness: 1170.0
#
# [5 rows x 30 columns]

# %%
tournament_sel = tournament_sel.applymap(extract_number).astype(float)
fps = fps.applymap(extract_number).astype(float)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharey=True)

custom_palette = ["#fd7f6f", "#7eb0d5", "#b2e061"]
for i, ax in enumerate(axes.flatten()):
# Select the dataset for the current box plot
    if i == 0:
        dataset = tournament_sel
        title = "Tournament Sel"
    elif i == 1:
        dataset = fps
        title = "Fps"
    elif i == 2:
        dataset = ranking_sel
        title = "Ranking Selection"
    
    # Create the box plot
    sns.boxplot(data=dataset, color=custom_palette[i], ax=ax)
    
    # Adjust y-axis limit to accommodate the maximum value
    ax.set_ylim(0, 5000)
    ax.set_xlabel(title)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
unpivoted_df1 = pd.melt(tournament_sel, var_name='Generation', value_name='Fitness_tournament_sel')
unpivoted_df2 = pd.melt(fps, var_name='Generation', value_name='Fitness_fps')
unpivoted_df3 = pd.melt(order_timeslots_crossover, var_name='Generation', value_name='Fitness_ranking_sel')
unpivoted_df = pd.merge(unpivoted_df1, unpivoted_df2, left_index=True, right_index=True)
unpivoted_df = pd.merge(unpivoted_df, unpivoted_df3, left_index=True, right_index=True)
unpivoted_df.drop(["Generation_x","Generation_y"], axis=1, inplace=True)
unpivoted_df
# Out:
#      Fitness_tournament_sel  Fitness_fps Generation  Fitness_ranking_sel
# 0                    4088.5       2270.0          1               4858.5
# 1                    3254.5       2562.5          1                818.5
# 2                    1966.5       2969.5          1               2878.5
# 3                    1067.5       2557.5          1               3289.5
# 4                    2815.0       1953.5          1               4078.5
# ..                      ...          ...        ...                  ...
# 295                   322.0       1592.0         30               1172.0
# 296                   514.0       1282.5         30               1875.5
# 297                  1036.5       1527.5         30               1609.0
# 298                   348.0       1635.5         30                581.5
# 299                   708.0       1760.5         30                279.0
#
# [300 rows x 4 columns]

# %%
# Reshape the data into a long format
df_long = unpivoted_df.melt(id_vars='Generation', value_vars=['Fitness_tournament_sel', 'Fitness_fps', 'Fitness_ranking_sel'],
                            var_name='Method', value_name='Fitness')
# Create the line plot
sns.lineplot(data=df_long, x='Generation', y='Fitness', hue='Method')

# Set plot title and y-axis limit
plt.title('Fitness by Generation')
plt.ylim(0)

# Display the plot
plt.show()
